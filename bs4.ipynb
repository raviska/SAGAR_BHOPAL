# %%
# !pip install quandl

# %%
import pandas as pd

# %%
import os

# %%
import quandl

# %%
import time

# %%
auth_tok = ".............."

# %%
data = quandl.get("WIKI/MSFT", trim_start = "2000-12-12", trim_end = "2018-12-01", authtoken = auth_tok)

# %%
data.head()
# Out:
#              Open   High    Low  ...   Adj. Low  Adj. Close  Adj. Volume
# Date                             ...
# 2000-12-12  57.81  60.00  56.75  ...  18.888988   19.431527   63106000.0
# 2000-12-13  60.50  60.50  56.81  ...  18.908959   19.055411   98360400.0
# 2000-12-14  57.94  58.73  55.38  ...  18.432990   18.472931   71201400.0
# 2000-12-15  51.05  52.00  47.75  ...  15.893378   16.372676  116899800.0
# 2000-12-18  49.00  50.00  47.00  ...  15.643744   15.913349  107187400.0
#
# [5 rows x 12 columns]

# %%
import datetime
quandl.ApiConfig.api_key = "................"
today = datetime.date.today()
start = (today - datetime.timedelta(days = 365*2)).strftime('%Y-%m-%d')
end = today

# %%
data2 = quandl.get_table('WIKI/PRICES', ticker=['AAPL', 'MSFT', 'GOOG', 'IVZ'], qopts = {'columns': ['ticker', 'date', 'adj_close']}, date ={'gte': start, 'lte': end}, paginate=False)

# %%
import sqlite3

# %%
conn = sqlite3.connect(':memory')

# %%
import datetime
quandl.ApiConfig.api_key =
today = datetime.date.today()
start = (today - datetime.timedelta(days = 365*2)).strftime('%Y-%m-%d')
end = (today - datetime.timedelta(days = 365)).strftime('%Y-%m-%d')
conn = sqlite3.connect(':memory')
quandl.ApiConfig.api_key = ""
data2 = quandl.get_table('WIKI/PRICES', ticker=['AAPL', 'MSFT'], qopts = {'columns': ['ticker', 'date', 'adj_close']}, date ={'gte': start, 'lte': end}, paginate=False)
data2.to_sql(name='HistoricPrices13', con = conn, index=False)
#print(data2)
cur = conn.cursor()
cur.execute('SELECT * FROM HistoricPrices13 ORDER BY 2,3')
#for row in cur:
  #print(row)
rows = cur.fetchall()
print(rows)
# Out:
# []

# %%
import quandl as q
import sqlite3 as sq

token = ""
token = None

data = q.get("WIKI/IVZ", authtoken=token)

conn = sq.connect("RC")
data.to_sql('IVZ', conn, if_exists='replace',
            dtype={'Date':'DATE', 'Price':'FLOAT'})
conn.commit()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
data
# Out:
#              Open   High    Low  ...   Adj. Low  Adj. Close  Adj. Volume
# Date                             ...
# 1995-08-25  33.62  34.12  33.62  ...   4.035961    4.081578    3541000.0
# 1995-08-28  33.88  33.88  33.25  ...   4.024429    4.054688    1418500.0
# 1995-08-29  33.75  33.88  33.12  ...   4.008695    4.054688     879000.0
# 1995-08-30  33.50  33.62  33.38  ...   4.040164    4.069212     436500.0
# 1995-08-31  33.62  33.62  33.25  ...   4.024429    4.054688     606500.0
# ...           ...    ...    ...  ...        ...         ...          ...
# 2018-03-21  32.58  33.55  32.54  ...  32.540000   32.940000    3744124.0
# 2018-03-22  32.45  32.62  31.36  ...  31.360000   31.450000    3983274.0
# 2018-03-23  31.53  31.71  30.66  ...  30.660000   30.720000    2925322.0
# 2018-03-26  31.40  32.18  31.06  ...  31.060000   32.130000    3999667.0
# 2018-03-27  32.17  32.24  31.06  ...  31.060000   31.360000    3904282.0
#
# [5685 rows x 12 columns]

# %%
#BeautifulSoup

# %%
from time import time, sleep
from random import randint
from IPython.core.display import clear_output
from requests import get
from bs4 import BeautifulSoup as soup
import matplotlib.pyplot as plt
import pandas as pd
from urllib.request import urlopen as uReq

# %%
my_url2 = "https://www.flipkart.com/search?q=mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&as-pos=1&as-type=RECENT&suggestionId=mobiles%7CMobiles&requestId=113d5472-8a66-4b88-93d8-40c4efb1666a&as-backfill=on"

# %%
uClient = uReq(my_url2)

# %%
page_html = uClient.read()

# %%
page_html
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch" />\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.21be2e.css" />\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta property="fb:page_id" content="102988293558"/>\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389"/>\n\t<meta name="robots" content="noodp" />\n\n\t<link rel=\'shortcut icon\' href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" />\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/>\n\n\t<meta property="og:type" content="website"/>\n\t<meta name="og_site_name" pr
# ...

# %%
uClient.close()

# %%
page_soup = soup(page_html, "html.parser")

# %%
containers = page_soup.findAll("div", {"class": "_1UoZlX"})

# %%
len(containers)
# Out:
# 24

# %%
print(soup.prettify(containers[0]))
# Out:
# <div class="_1UoZlX">
#  <a class="_31qSD5" href="/redmi-8-sapphire-blue-64-gb/p/itmd1c68a1a86f5e?pid=MOBFKPYDENDXZZ7U&amp;lid=LSTMOBFKPYDENDXZZ7U9TT5NP&amp;marketplace=FLIPKART&amp;srno=s_1_1&amp;otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&amp;fm=organic&amp;iid=491c6971-df1e-4597-973e-6ed88ae3959e.MOBFKPYDENDXZZ7U.SEARCH&amp;ssid=860z43hvwg0000001597398309730&amp;qH=eb4af0bf07c16429" rel="noopener noreferrer" target="_blank">
#   <div class="_3SQWE6">
#    <div class="_1OCn9C">
#     <div>
#      <div class="_3BTv9X" style="height:200px;width:200px">
#       <img alt="Redmi 8 (Sapphire Blue, 64 GB)" class="_1Nyybr" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg"/>
#      </div>
#     </div>
#    </div>
#    <div class="_2lesQu">
#     <div class="_1O_CiZ">
#      <span class="_1iHA1p">
#       <div class="_2kFyHg">
#        <label>
# ...

# %%
container = containers[0]
price = container.findAll("div", {"class": "_1vC4OE _2rQ-NK"})
price[0].text
# Out:
# '₹9,999'

# %%
for container in containers:
  price = container.findAll("div", {"class": "_1vC4OE _2rQ-NK"})
  print(price[0].text)
# Out:
# ₹9,999
# ₹7,499
# ₹7,499
# ₹9,090
# ₹9,999
# ₹9,999
# ₹6,999
# ₹9,999
# ₹14,999
# ₹12,999
# ₹14,999
# ₹12,999
# ₹8,999
# ₹1,399
# ₹15,999
# ₹7,999
# ₹7,999
# ₹17,499
# ₹18,499
# ₹1,450
# ₹18,499
# ₹7,999
# ₹6,499
# ₹6,499

# %%
for container in containers:
  discount= container.findAll("div", {"class": "VGWI6T"})
  print(discount[0].text)
# Out:
# 9% off
# 16% off
# 16% off
# 6% off
# 9% off
# 9% off
# 12% off
# 16% off
# 6% off
# 13% off
# 6% off
# 13% off
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-139-fa1660797600> in <module>()
#       1 for container in containers:
#       2   discount= container.findAll("div", {"class": "VGWI6T"})
# ----> 3   print(discount[0].text)
#
# IndexError: list index out of range

# %%
discount = container.findAll(("div", {"class": "VGWI6T _2YXy_Y"}))
